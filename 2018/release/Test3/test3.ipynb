# %%
# Initialisation Cell
from IPython.display import display, HTML, Javascript
from math import *
import numpy as np
import numpy.testing as nt
import time

# %% [markdown]
# # Numerical Analysis II - Test 2 Deferred
#
#
# ## Instructions
#
# * You may only access https://moodle.ms.wits.ac.za/tests/ during the test and **NOT** normal moodle (i.e. https: //moodle.ms.wits.ac.za/moodle/ )
# * All machines are being logged and anyone caught logging into the regular Moodle listed above will be given **zero**.
# * Anyone caught trying to log into someone else's account will be given **zero**.
# * Anyone attempting to use brought in code, notes or any other materials will be given **zero**.
# * To launch jupyter notebook correctly. Using VMUSER, open the terminal and type `/usr/local/anaconda3/bin/jupyter-notebook`
# * Read all the instructions carefully.
# * **DO NOT change the name of the notebook in any way!**
# * The test will run from 12:00 - 13:30 (this includes the extra time students). At 13:30 Moodle will no longer take submissions so ensure that you have uploaded your notebook by at least 11:55.
# * DO NOT rename the file. Simply answer all questions within the notebook and resubmit the file.
# * There are 105 marks available. There are 5 MCQ questions and 5 programming questions.

# %% [markdown]
# ## MCQ Questions
#
# In each of the MCQ questions there is only one correct answer. Once you have decided an answer in each question, uncomment out the response of your choosing from the corresponding python function.
#
# There are 5 MCQ questions.
#
# ***
#
# ### Question 1
#
# When implementing a least squares solution, the distance we are minimising is which of the following: [3 marks ]
#
# * (a) The sum of orthogonal distances between all points and the fit
# * (b) The sum of vertical distances between all points and the fit
# * (c) The sum of vertical and orthogonal distances between all points and the fit
# * (d) There is no minimisation. We actually seek the function which passes through all points
# * (e) None of the above

# %%
def question1():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question1() in ['a', 'b', 'c', 'd', 'e'])
print('Function is returning a plausible response')

# %%
# Hidden evaulation 
# 3 Marks

# %% [markdown]
# ### Question 2
#
# The family of solutions for the ODE $y^\prime = y$, have what kind of stability: [3 marks ]
#
# * (a) Stable solutions
# * (b) Unstable solutions
# * (c) Asymptotically stable solutions
# * (d) Insensitive solutions
# * (e) None of the above

# %%
def question2():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question2() in ['a', 'b', 'c', 'd', 'e'])
print('Function is returning a plausible response')

# %%
# Hidden evaulation 
# 3 Marks

# %% [markdown]
# ### Question 3
#
# Over time, errors in unstable solutions of ODEs: [3 marks ]
#
# * (a) Grow with time
# * (b) Decrease with time
# * (c) Remain the same
# * (d) Rapidly decrease with time
# * (e) None of the above

# %%
def question3():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question3() in ['a', 'b', 'c', 'd', 'e'])
print('Function is returning a plausible response')

# %%
# Hidden evaulation 
# 3 Marks

# %% [markdown]
# ### Question 4
#
# Applying cubic splines to *four* data points yields how many cubic equations? [3 marks ]
#
# * (a) 4
# * (b) 3
# * (c) 5
# * (d) Depends on the data
# * (e) None of the above

# %%
def question4():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question4() in ['a', 'b', 'c', 'd', 'e'])
print('Function is returning a plausible response')

# %%
# Hidden evaulation 
# 3 Marks

# %% [markdown]
# ### Question 5
#
# Interpolating over an increasingly large number of points may lead to: [3 marks ]
#
# * (a) A perfectly suitable polynomial
# * (b) Gibbs phenomenon
# * (c) Runge phenomenon
# * (d) (a) or (b)
# * (e) None of the above

# %%
def question5():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question5() in ['a', 'b', 'c', 'd', 'e'])
print('Function is returning a plausible response')

# %%
# Hidden evaulation 
# 3 Marks

# %% [markdown]
# ## Programming Questions
#
# Complete the following problems:
#
#
# ### Question 1 [15 Marks]
#
# Write a function that will produce a Lagrange interpolating polynomial $P(x)$ and evaluate it at an array of points `xstar`, outputting the resulting `P(xstar)` values. The degree of the polynomial will be passed with input `degree`. The function should use the most appropriate $x$ values for each `xstar` value and polynomial degree (i.e. it should be as accurate as possible). The inputs `x`, `y` and `xstar` are all numpy arrays, and the corresponding output an array. If the data are not consistent, i.e. `x` and `y` do not have the same length, the function should return the string `'length of data not consistent'`.
#
# **Recall:**
# \begin{eqnarray*} L_{n,k}(x)&=&\frac{(x-x_0)\ldots(x-x_{k-1})(x-x_{k+1})\ldots(x-x_n)}{(x_k-x_0)\ldots(x_k-x_{k-1})(x_k-x_{k+1})\ldots(x_k-x_n)}\\
# &=&\prod_{i=0,i\neq k}^n \frac{(x-x_i)}{(x_k-x_i)}.\end{eqnarray*}
# and:
# \begin{equation*}
# P(x)=L_{n,0}(x)f(x_0)+L_{n,1}(x)f(x_1)+\ldots +L_{n,n}(x)f(x_n)
# \end{equation*}

# %%
def lagrange_polynomial_evaluator(x, y, xstar, degree):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
xval   = np.array([0,1,2,3,4])
yval   = np.array([5,11,101,1445])
xstar  = np.array([0.5, 1.5, 2.5, 3.5])
degree = 2
nt.assert_string_equal('length of data not consistent', lagrange_polynomial_evaluator(xval, yval, xstar, degree))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
xval  = np.array([0,1,2,3,4])
yval  = np.array([5,11,101,473,1445])
xstar = np.array([0.5, 1.5, 2.5, 3.5])
degree = 4
nt.assert_array_almost_equal([5.1875, 35.9375, 234.6875, 859.4375], lagrange_polynomial_evaluator(xval, yval, xstar, degree))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
xval  = np.array([0,1,2,3,4])
yval  = np.array([5,11,101,473,1445])
xstar = np.array([0.5, 1.5, 2.5, 3.5])
degree = 2
nt.assert_array_almost_equal([ -2.5 ,  45.5 , 251.75, 884.  ], lagrange_polynomial_evaluator(xval, yval, xstar, degree))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 12 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %% [markdown]
# ### Question 2 [15 Marks]
#
# Write a function which performs Euler's method for solving ODEs. The function `euler` should take as inputs, `f` (i.e. $y^\prime = f(x, y)$), the initial value `x0` and `y0`. It should also take the step-size `h`, the final $x$ approximation point `xf` and the true analytical solution `tf` as an anonymous function. The function should return an array of the successive $y$ approximations at each step, as well as the relative error between this approximation and the value of the true solution.

# %%
def euler(f, x0, y0, h, xf, tf):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 3 Marks
f  = lambda x, y: x + y
h  = 0.1
x0 = 0
y0 = 1
h  = 0.1
xf = 0.4
tf = lambda x: -x + 2*np.exp(x) - 1
nt.assert_array_almost_equal([1.1, 1.2200000000000002, 1.362, 1.5282], euler(f, x0, y0, h, xf, tf)[0])
print('All tests passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
f  = lambda x, y: x + y
h  = 0.1
x0 = 0
y0 = 1
h  = 0.1
xf = 0.4
tf = lambda x: -x + 2*np.exp(x) - 1
t1 = [0.009314101130461293,
       0.018350028239222185,
       0.026946588900297854,
       0.03501368134115821]
nt.assert_array_almost_equal(t1, euler(f, x0, y0, h, xf, tf)[1])
print('All tests passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 5 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %%
# Run this test cell to check your code
# Do not delete this cell
# 5 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %% [markdown]
# ### Question 3 [20 Marks]
#
# Write a function `ODE_solver` which solves a given ODE with Euler's Method, Modified Euler's method and Runge-Kutta 4. The function should take in as input the function `f` (the same format as in Question 2), the initial value `x0` and `y0`, the step-size `h` and the final $x$ value `xf`. The function `ODE_solver` should return a matrix of 3 columns, where column one is the approximation for each $y$ value using Euler's Method, column 2 Modified Euler's Method and column 3 is the approximations using the RK4 method.
#
# **Recall:**
#
#
# \begin{equation*}
# y_{i+1}=y_i+{1\over 6}(k_1+2 k_2+2 k_3+k_4),
# \end{equation*}
# \begin{eqnarray*}
# k_1 &=& hf(x_i,y_i)\\
# k_2 &=& hf(x_i+{h\over 2} ,y_i+{k_1\over 2} )\\
# k_3 &=& hf(x_i+{h\over 2} ,y_i+{k_2\over 2})\\
# k_4 &=& hf(x_i+h ,y_i+k_3),
# \end{eqnarray*}
# \begin{equation*}
# y_{i+\frac{1}{2}}=y_i+f(x_i,y_i) {h\over 2}.
# \end{equation*}
# \begin{equation*}
# y_{i+\frac{1}{2}}^\prime=f(x_{i+1/2},y_{i+1/2}),
# \end{equation*}
# \begin{equation*}
# y_{i+1}=y_i+ f(x_{i+1/2},y_{i+1/2}) h
# \end{equation*}

# %%
def ODE_solver(f, x0, y0, h, xf):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
y0 = 1
x0 = 0
h  = 0.1
f  = lambda x, y: x + y
xf = 0.4
nt.assert_array_almost_equal(np.array([1.1   , 1.22  , 1.362 , 1.5282]), ODE_solver(f, x0, y0, h, xf)[:, 0])
print('All tests passed')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
y0 = 1
x0 = 0
h  = 0.1
f  = lambda x, y: x + y
xf = 0.4
nt.assert_array_almost_equal(np.array([1.11, 1.24205, 1.39846525, 1.5818041]), ODE_solver(f, x0, y0, h, xf)[:, 1])
print('All tests passed')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
y0 = 1
x0 = 0
h  = 0.1
f  = lambda x, y: x + y
xf = 0.4
nt.assert_array_almost_equal([1.11034167, 1.24280514, 1.39971699, 1.58364848], ODE_solver(f, x0, y0, h, xf)[:, 2])
print('All tests passed')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
y0 = 1
x0 = 0
h  = 0.1
f  = lambda x, y: x + y
xf = 0.4
tans = [[1.1     , 1.11    , 1.110342],
       [1.22    , 1.24205 , 1.242805],
       [1.362   , 1.398465, 1.399717],
       [1.5282  , 1.581804, 1.583648]]
nt.assert_array_almost_equal(tans, ODE_solver(f, x0, y0, h, xf))
print('All tests passed')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 4 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %%
# Run this test cell to check your code
# Do not delete this cell
# 5 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %%
# Run this test cell to check your code
# Do not delete this cell
# 5 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %% [markdown]
# ### Question 4 [20 Marks]
#
# Write a function `poly_least_squares` which takes as input some data points `x` ($x$ coordinate) and `y` ($y$ coordinate). It also takes in `order` the degree of polynomial to fit to the given data $(x_i, y_i)$. An `order` value of 1 implies a straight line fit (i.e. $a_0$ and $a_1$). The function should return 4 outputs, the matrix `A`, the vector `b` , the solution to the system `xstar` (the resulting coefficients of the fit) and the total residual error of the fit (i.e. $r^2$).
#
# **Recall**:
# \begin{equation*}
# f(x)=P_m(x)=a_0+a_1 x+\cdots+a_m x^m
# \end{equation*}
# \begin{eqnarray*}
# a_0 \;n &+& a_1\sum_{i=1}^n x_i+a_2\sum_{i=1}^n x_i^2+\cdots+a_m\sum_{i=1}^n
# x_i^m = \sum_{i=1}^n y_i\\
# a_0 \sum_{i=1}^n x_i &+& a_1\sum_{i=1}^n x_i^2+a_2\sum_{i=1}^n x_i^3+\cdots+
# a_m\sum_{i=1}^n x_i^{m+1} = \sum_{i=1}^n x_i y_i\\
# a_0 \sum_{i=1}^n x_i^2 &+& a_1\sum_{i=1}^n x_i^3+a_2\sum_{i=1}^n x_i^4+\cdots+
# a_m\sum_{i=1}^n x_i^{m+2} = \sum_{i=1}^n x_i^2 y_i\\
# \vdots && \vdots\\
# a_0 \sum_{i=1}^n x_i^m &+& a_1\sum_{i=1}^n x_i^{m+1}+a_2\sum_{i=1}^n x_i^{m+2}+
# \cdots+ a_m\sum_{i=1}^n x_i^{2m} = \sum_{i=1}^n x_i^m y_i
# \end{eqnarray*}
#
# **Note:** Do not attempt to use any regression or polynomial built-in functions as these will be deleted from the namespace in the hidden tests.

# %%
def poly_least_squares(x, y, order):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([2.1, 7.7, 13.6, 27.2, 40.9, 61.1])
tans = [[  6.,  15.,  55.],
        [ 15.,  55., 225.],
        [ 55., 225., 979.]]
nt.assert_array_almost_equal(tans, poly_least_squares(x, y, 2)[0])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([2.1, 7.7, 13.6, 27.2, 40.9, 61.1])
tans = [ 152.6,  585.6, 2488.8]
nt.assert_array_almost_equal(tans, poly_least_squares(x, y, 2)[1])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([2.1, 7.7, 13.6, 27.2, 40.9, 61.1])
tans = [2.47857143, 2.35928571, 1.86071429]
nt.assert_array_almost_equal(tans, poly_least_squares(x, y, 2)[2])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 2 Marks
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([2.1, 7.7, 13.6, 27.2, 40.9, 61.1])
tans = 1.7053025658242404e-13
nt.assert_array_almost_equal(tans, poly_least_squares(x, y, 2)[3])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 6 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %%
# Run this test cell to check your code
# Do not delete this cell
# 4 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %%
# Run this test cell to check your code
# Do not delete this cell
# 4 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %% [markdown]
# ### Question 5 [20 Marks]
#
# Write a function `cubic_splines` which takes input data `x`, `y` and optional `*pt`. The function should apply cubic splines to the data points. Specifically, if no optional input is passed, then the function should return the array's of the coefficients of the cubic splines, i.e. $a_i's$, $b_i's$, $c_i's$ and $d_i's$ (i.e. 4 outputs `a, b, c, d`, where each one is an array). Otherwise, if a point is passed as additional input, then the function should return only the approximation of the appropriate cubic spline for the given point.
#
# **Recall:**
#
# \begin{equation*}
# s_i(x) = f_i + b_i(x-x_i) + c_i(x-x_i)^2+d_i(x-x_i)^3.
# \end{equation*}
# where $a_i = f_i$
# \begin{eqnarray*}
# b_i &=& \dfrac{f_{i+1}-f_i}{h_i}-\dfrac{h_i}{3}(2c_i + c_{i+1}), \\
# d_i &=& \dfrac{c_{i+1}-c_i}{3h_i},
# \end{eqnarray*}
# \begin{equation*}
# h_i = x_{i+1} - x_i.
# \end{equation*}
# $$
# \begin{bmatrix}
# 1 &  &  & \\
# h_1 & 2(h_1+h_2)  &h_2  & \\
#   \ddots &\ddots  &\ddots & \\
#  & h_{n-2} & 2(h_{n-2}+h_{n-1})  & h_{n-1} \\
#   &  &  & 1
# \end{bmatrix}
# \begin{Bmatrix}
# c_1\\
# c_2\\
# \vdots\\
# c_{n-1}\\
# c_n
# \end{Bmatrix}
# \begin{bmatrix}
# 0\\
# 3(f[x_3,x_2]-f[x_2,x_1])\\
# \vdots\\
# 3(f[x_n,x_{n-1}]-f[x_{n-1},x_{n-2}])\\
# 0
# \end{bmatrix}.\nonumber
# $$

# %%
def cubic_splines(x, y, *pt):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
x  = np.array([3, 4.5, 7, 9])
y  = np.array([2.5, 1, 2.5, 0.5])
t1 = [2.5, 1. , 2.5]
t2 = [-1.41977186, -0.16045627,  0.02205323]
t3 = [ 0.,  0.83954373, -0.76653992,  0.]
t4 = [ 0.18656527, -0.21414449,  0.12775665]
nt.assert_array_almost_equal(t1, cubic_splines(x, y)[0])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
x  = np.array([3, 4.5, 7, 9])
y  = np.array([2.5, 1, 2.5, 0.5])
t1 = [2.5, 1. , 2.5]
t2 = [-1.41977186, -0.16045627,  0.02205323]
t3 = [ 0.,  0.83954373, -0.76653992,  0.]
t4 = [ 0.18656527, -0.21414449,  0.12775665]
nt.assert_array_almost_equal(t2, cubic_splines(x, y)[1])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
x  = np.array([3, 4.5, 7, 9])
y  = np.array([2.5, 1, 2.5, 0.5])
t1 = [2.5, 1. , 2.5]
t2 = [-1.41977186, -0.16045627,  0.02205323]
t3 = [ 0.,  0.83954373, -0.76653992,  0.]
t4 = [ 0.18656527, -0.21414449,  0.12775665]
nt.assert_array_almost_equal(t3, cubic_splines(x, y)[2])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
x  = np.array([3, 4.5, 7, 9])
y  = np.array([2.5, 1, 2.5, 0.5])
t1 = [2.5, 1. , 2.5]
t2 = [-1.41977186, -0.16045627,  0.02205323]
t3 = [ 0.,  0.83954373, -0.76653992,  0.]
t4 = [ 0.18656527, -0.21414449,  0.12775665]
nt.assert_array_almost_equal(t4, cubic_splines(x, y)[3])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Marks
x = np.array([3, 4.5, 7, 9])
y = np.array([2.5, 1, 2.5, 0.5])
nt.assert_almost_equal(1.102889733840304, cubic_splines(x, y, 5))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 8 Marks
# HIDDEN TEST
# Note nothing will be printed to screen

# %%
# Run this test cell to check your code
# Do not delete this cell
# 8 Marks
# HIDDEN TEST
# Note nothing will be printed to screen
