# %%
# Initialisation Cell
from matplotlib import pyplot as plt
from IPython.display import display, HTML, Javascript
from math import *
import numpy as np
import numpy.testing as nt

# %% [markdown]
# # Numerical Analysis II - Test 1
#
#
# ## Instructions
#
# * You may only access https://moodle.ms.wits.ac.za/tests/ during the test and **NOT** normal moodle (i.e. https: //moodle.ms.wits.ac.za/moodle/ )
# * All machines are being logged and anyone caught logging into the regular Moodle listed above will be given **zero**.
# * Anyone caught trying to log into someone else's account will be given **zero**.
# * Anyone attempting to use brought in code, notes or any other materials will be given **zero**.
# * Read all the instructions carefully.
# * **DO NOT change the name of the notebook in any way!**
# * The test will run from 10:15 - 12:00 (this includes the extra time students). At 12:00 Moodle will no longer take submissions so ensure that you have uploaded your notebook by at least 11:55.
# * DO NOT rename the file. Simply answer all questions within the notebook and resubmit the file.
# * There are 105 marks available. There are 5 MCQ questions and 5 programming questions.

# %% [markdown]
# ## MCQ Questions
#
# In each of the MCQ questions there is only one correct answer. Once you have decided an answer in each question, uncomment out the response of your choosing from the corresponding python function.
#
# There are 5 MCQ questions.
#
# ***
#
# ### Question 1
#
# Is Newton's method guaranteed to find the zero of any continuous function that has a zero and for any starting point? [3 marks ]
#
# * (a) Always
# * (b) No - it does not work on continuous functions
# * (c) No - the method is unlikely to converge on starting points far from the root
# * (d) Yes - if the function exhibits *bumpy* behaviour

# %%
def question1():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question1() in ['a', 'b', 'c', 'd'])
assert(question1() == 'c')
print('Function is returning a plausible response and is correct')

# %% [markdown]
# ### Question 2
#
# What Taylor series expansion would you take in order to obtain an expression for the *Central Difference Approximation*: [3 marks ]
#
# * (a) $f(x - h)$
# * (b) $f(x + h)$
# * (c) $f(x)$
# * (d) $f(x - h)$ and $f(x + h)$

# %%
def question2():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question2() in ['a', 'b', 'c', 'd'])
assert(question2() == 'd')
print('Function is returning a plausible response and is correct')

# %% [markdown]
# ### Question 3
#
# The method of False position makes use of which interpolation between $(a, f(a))$ and $(b, f(b))$ [3 marks ]
#
# * (a) Linear
# * (b) It does not use interpolation
# * (c) Quadratic
# * (d) It uses the tangent NOT the interpolant

# %%
def question3():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question3() in ['a', 'b', 'c', 'd'])
assert(question3() == 'a')
print('Function is returning a plausible response and is correct')

# %% [markdown]
# ### Question 4
#
# Given an initial bracket of $[0, 100]$, how many steps of the Bisection Method are required to reduce the bracket size below $10^{-5}$? [3 marks ]
#
# * (a) 24.2535
# * (b) 25
# * (c) 24
# * (d) 26

# %%
def question4():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question4() in ['a', 'b', 'c', 'd'])
assert(question4() == 'b')
print('Function is returning a plausible response and is correct')

# %% [markdown]
# ### Question 5
#
# Implementing Romberg Integration with initial approximations $T_0^k$ computed using Trapezoidal rule, what will be the order of error associated with $T_4^k$? [3 marks ]
#
# * (a) $\mathcal{O}(h^2)$
# * (b) $\mathcal{O}(h^{10})$
# * (c) $\mathcal{O}(h^8)$
# * (d) $\mathcal{O}(h^6)$

# %%
def question5():
    """
    Uncomment your choice to the question
    """
    #return 'a'
    #return 'b'
    #return 'c'
    #return 'd'
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert(question5() in ['a', 'b', 'c', 'd'])
assert(question5() == 'b')
print('Function is returning a plausible response and is correct')

# %% [markdown]
# ## Programming Questions
#
# ### Question  1
#
# Write a function, `first_deriv_approx`, which takes as input, the anonymous function `f`, a perturbation `h` and point of evaluation `x`. The function should return all of approximations obtained by the standard forward, backward and central difference formulae (in this order). [15 Marks]

# %%
def first_deriv_approx(f, h, x):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f = lambda x: np.sin(x)
h = 0.005
x = np.pi
nt.assert_almost_equal(-0.9999958333385203, first_deriv_approx(f, h, x)[0], err_msg = 'Incorrect Solution')
print('Test case passsed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f = lambda x: np.sin(x)
h = 0.005
x = np.pi
nt.assert_almost_equal(-0.9999958333385205, first_deriv_approx(f, h, x)[1], err_msg = 'Incorrect Solution')
print('Test case passsed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f = lambda x: np.sin(x)
h = 0.005
x = np.pi
nt.assert_almost_equal(-0.9999958333385205, first_deriv_approx(f, h, x)[2], err_msg = 'Incorrect Solution')
print('Test case passsed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f = lambda x: np.sin(x)
h = 0.005
x = np.pi
nt.assert_almost_equal((-0.9999958333385203, -0.9999958333385205, -0.9999958333385205), first_deriv_approx(f, h, x), err_msg = 'Incorrect Solution')
print('Test case passsed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# Hidden case(s): 
# 11 Marks

# %% [markdown]
# ### Question 2
#
# Write a function `first_deriv_approx_data`, which takes as inputs, a vector of data points `x` and its corresponding $f(x)$ values `y`. The function should return the best possible approximations possible using the forward, backward and central difference formulae, i.e. the function should use the most accurate formula for each and every point. Should `x` or `y` be empty, then the function should return the string, `'Insufficient Data'`. [20 Marks]

# %%
def first_deriv_approx_data(x, y):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
x = np.array([1.1, 1.2, 1.3, 1.4]) 
y = np.array([9.025013, 11.02318, 13.46374, 16.44465])
nt.assert_array_almost_equal([22.193635, 27.10735 ], first_deriv_approx_data(x, y)[1:-1])
print("Test case passed!!!")

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
x = np.array([1.1, 1.2, 1.3, 1.4]) 
y = np.array([9.025013, 11.02318, 13.46374, 16.44465])
nt.assert_almost_equal(19.98167000000003,  first_deriv_approx_data(x, y)[0])
print("Test case passed!!!")

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
x = np.array([1.1, 1.2, 1.3, 1.4]) 
y = np.array([9.025013, 11.02318, 13.46374, 16.44465])
nt.assert_almost_equal(29.809100000000036,  first_deriv_approx_data(x, y)[-1])
print("Test case passed!!!")

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
x = np.array([1.1, 1.2, 1.3, 1.4]) 
y = np.array([9.025013, 11.02318, 13.46374, 16.44465])
nt.assert_array_almost_equal(np.array([19.98167 , 22.193635, 27.10735 , 29.8091  ]), first_deriv_approx_data(x, y))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 8 Marks

# %%
# Run this test cell to check your code
# Do not delete this cell
# 8 Marks

# %% [markdown]
# ### Question 3
#
# Write a function `root_finder`, which takes as inputs, the anonymous functions `f` and derivative `g`, the left and right endpoints `a` and `b` respectively. It should also take `xstar` an initial approximation and a tolerance `tol`. The function should implement BOTH the bisection method and Newton's method subject to the given inputs. It should return the final approximation to the root as well as the number of iterations required to achieve the approximation for each method. The returned values should be of the form: `bisection_approx, bisection_iterations, newton_approx, newton_iterations`. You **must** control the bisection method's tolerance with `abs(a - b)` and `abs(xnew - xold)` for Newton's method. The bisection search should return the midpoint of the final interval. [15 Marks]

# %%
def root_finder(f, g, a, b, xstar, tol):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f     = lambda x: x**2 - 1
g     = lambda x: 2*x
a     = 0
b     = 3
xstar = 3
tol   = 1e-7
nt.assert_almost_equal(0.9999999850988388, root_finder(f, g, a, b, xstar, tol)[0])
print("Test case passed!!!")

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f     = lambda x: x**2 - 1
g     = lambda x: 2*x
a     = 0
b     = 3
xstar = 3
tol   = 1e-7
nt.assert_almost_equal(25, root_finder(f, g, a, b, xstar, tol)[1])
print("Test case passed!!!")

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f     = lambda x: x**2 - 1
g     = lambda x: 2*x
a     = 0
b     = 3
xstar = 3
tol   = 1e-7
nt.assert_almost_equal(1, root_finder(f, g, a, b, xstar, tol)[2])
print("Test case passed!!!")

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f     = lambda x: x**2 - 1
g     = lambda x: 2*x
a     = 0
b     = 3
xstar = 3
tol   = 1e-7
nt.assert_almost_equal(6, root_finder(f, g, a, b, xstar, tol)[3])
print("Test case passed!!!")

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f     = lambda x: x**2 - 1
g     = lambda x: 2*x
a     = 0
b     = 3
xstar = 3
tol   = 1e-7
nt.assert_almost_equal((0.9999999850988388, 25, 1.0, 6), root_finder(f, g, a, b, xstar, tol))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 10 Marks

# %% [markdown]
# ### Question 4
#
# Recall that the *composite midpoint method* for the double integral is defined by:
# \begin{equation}
# \int_a^b \int_c^d f(x,y) dydx = h_xh_y \sum_{i=0}^{n_x-1} \sum_{j=0}^{n_y-1} f(a + \frac{h_x}{2} + ih_x, c + \frac{h_y}{2} + jh_y)\thinspace.
# \end{equation}
# Write a function `midpoint_method_double`, which takes as inputs, the function `f`, the integral bounds `a, b, c, d` and the number of intervals in the dimension of $x$, `nx` and the dimension $y$ `ny`. The function should return the approximate integral value. [20 Marks]

# %%
def midpoint_method_double(f, a, b, c, d, nx, ny):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 5 Marks
f  = lambda x, y: 2*x + y
a  = 2
b  = 3
c  = 0
d  = 2
nx = 15
ny = 15

nt.assert_almost_equal(12, midpoint_method_double(f, a, b, c, d, nx, ny))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 15 Marks

# %% [markdown]
# ### Question 5
#
# Write a function `integral_approx`, which takes as inputs, the anonymous function `f`, the lower and upper integral bound `a` and `b`, as well as the number of panels `n`. The function should implement **BOTH** the trapezoidal rule and Simpson's 1/3 rule. The function should return both the respective approximations in the order `trapezoidal, simpsons`. Recall the equations:
# \begin{equation*}
# I = \int_a^b f(x)dx  \approx {h\over 2}\left[f_0+2(f_1+f_2+\cdots+f_{n-1})+f_n\right],
# \end{equation*}
# for the Trapezoidal rule and:
# \begin{equation*}
# \int_a^b f(x)dx\approx {h\over 3}\left[ f_0+4(f_1+f_3+\cdots f_{n-1})+
# 2(f_2+f_4+\cdots+f_{n-2}) +f_n \right]
# \end{equation*}
# for the Simpson's 1/3 rule. The function should return the string `'Not enough panels requested'` if $n < 1$ for both methods (i.e. the string repeated for both elements of the tuple). It should also return the string, `'Only even number of panels acceptable'` if $n$ is not even for the Simpsons 1/3 Method.  [20 Marks]

# %%
def integral_approx(f, a, b, n):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f = lambda x: (1 + x**2)**(-1)
a = 0
b = 1
n = 6
nt.assert_almost_equal(0.7842407666178159, integral_approx(f, a, b, n)[0])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f = lambda x: (1 + x**2)**(-1)
a = 0
b = 1
n = 6
nt.assert_almost_equal(0.7853979452340107, integral_approx(f, a, b, n)[1])
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 1 Mark
f = lambda x: (1 + x**2)**(-1)
a = 0
b = 1
n = 6
nt.assert_almost_equal((0.7842407666178159, 0.7853979452340107), integral_approx(f, a, b, n))
print('Test case passed!!!')

# %%
# Run this test cell to check your code
# Do not delete this cell
# 7 Marks

# %%
# Run this test cell to check your code
# Do not delete this cell
# 5 Marks

# %%
# Run this test cell to check your code
# Do not delete this cell
# 5 Marks
